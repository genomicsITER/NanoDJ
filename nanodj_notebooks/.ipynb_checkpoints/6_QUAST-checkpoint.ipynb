# %% [markdown]
# ## Comparing assemblies with QUAST
#
# [QUAST](https://github.com/ablab/quast) is a genome assembly evaluation tool. It builds comparisons between multiple assemblies (with and without reference). QUAST computes some metrics and graphs and outputs all this information as an interactive html.
#
# The command consists on the FASTA assembly files (any number of assemblies) followed by two options:
#
# -R to pass the reference genome.
# -o to define the output directory name.

# %%
quast.py -h
# Out:
# QUAST: Quality Assessment Tool for Genome Assemblies
# Version: 5.0.0.dev0, e1c336f
#
# Usage: python /opt/conda/bin/quast.py [options] <files_with_contigs>
#
# Options:
# -o  --output-dir  <dirname>       Directory to store all result files [default: quast_results/results_<datetime>]
# -r                <filename>      Reference genome file
# -g  --features [type:]<filename>  File with genomic feature coordinates in the reference (GFF, BED, NCBI or TXT)
#                                   Optional 'type' can be specified for extracting only a specific feature type from GFF
# -m  --min-contig  <int>           Lower threshold for contig length [default: 500]
# -t  --threads     <int>           Maximum number of threads [default: 25% of CPUs]
#
# Advanced options:
# -s  --scaffolds                       Assemblies are scaffolds, split them and add contigs to the comparison
# ...

# %%
quast.py data/agalactiae/canu_output data/agalactiae/flye_output 
         -R data/agalactiae/reference/NZ_CP010867.1_Ref_MODIFICADA.fasta 
         -o agalactiae_quast
