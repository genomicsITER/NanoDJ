# %% [markdown]
# # Assembly with the Canu pipeline
#
# [Canu](https://github.com/marbl/canu) is a popular assembler based on Celera Assembler and built specifically to work with ONT reads. It consists on a 4-step pipeline that generates a 'draft assembly' without reference. In order to get better results, Canu is often used with tools that improves it result. In this notebook, we will build a popular Canu pipeline using Canu + Racon + Pilon.
#
# Canu works with either FASTA or FASTQ files (compressed and uncompressed), but FASTQ format is needed to run the next steps and complete the full pipeline. Help page can be shown with "canu -h" command. These are the parameters needed for running Canu with our data:
#
# - -p and -d: Assembly files prefix and output directory. Both parameters can be the same and output directory doesn't have to exist before execution.
# - genomeSize: The estimated genome size. In our case, 2.1 mbp so we write '2.1m'. We can put letter g for gbp or k for kbp as well.
# - -nanopore-raw: The path to our reads in FASTQ.

# %%
canu -p agalactiae \
     -d data/agalactiae/canu_output \
     genomeSize=4.6m \
     useGrid=false \
     minReadLength=50 \
     minOverlapLength=50 \
     -nanopore-raw data/agalactiae/merged-output.fasta
# Out:
# -- Canu snapshot v1.7 +137 changes (r8829 73d5caa1b1087b65f7853ecbebc1bb1dcbd1bc14)
# --
# -- CITATIONS
# --
# -- Koren S, Walenz BP, Berlin K, Miller JR, Phillippy AM.
# -- Canu: scalable and accurate long-read assembly via adaptive k-mer weighting and repeat separation.
# -- Genome Res. 2017 May;27(5):722-736.
# -- http://doi.org/10.1101/gr.215087.116
# --
# -- Read and contig alignments during correction, consensus and GFA building use:
# --   Šošic M, Šikic M.
# --   Edlib: a C/C ++ library for fast, exact sequence alignment using edit distance.
# --   Bioinformatics. 2017 May 1;33(9):1394-1395.
# --   http://doi.org/10.1093/bioinformatics/btw753
# --
# -- Overlaps are generated using:
# --   Berlin K, et al.
# --   Assembling large genomes with single-molecule sequencing and locality-sensitive hashing.
# --   Nat Biotechnol. 2015 Jun;33(6):623-30.
# --   http://doi.org/10.1038/nbt.3238
# --
# --   Myers EW, et al.
# --   A Whole-Genome Assembly of Drosophila.
# --   Science. 2000 Mar 24;287(5461):2196-204.
# --   http://doi.org/10.1126/science.287.5461.2196
# --
# -- Corrected read consensus sequences are generated using an algorithm derived from FALCON-sense:
# --   Chin CS, et al.
# --   Phased diploid genome assembly with single-molecule real-time sequencing.
# --   Nat Methods. 2016 Dec;13(12):1050-1054.
# --   http://doi.org/10.1038/nmeth.4035
# --
# -- Contig consensus sequences are generated using an algorithm derived from pbdagcon:
# --   Chin CS, et al.
# --   Nonhybrid, finished microbial genome assemblies from long-read SMRT sequencing data.
# --   Nat Methods. 2013 Jun;10(6):563-9
# --   http://doi.org/10.1038/nmeth.2474
# --
# -- CONFIGURE CANU
# --
# -- Detected Java(TM) Runtime Environment '1.8.0_162' (from 'java').
# -- Detected gnuplot version '4.6 patchlevel 6' (from 'gnuplot') and image format 'png'.
# -- Detected 2 CPUs and 4 gigabytes of memory.
# -- No grid engine detected, grid disabled.
# --
# --                            (tag)Concurrency
# --                     (tag)Threads          |
# --            (tag)Memory         |          |
# --        (tag)         |         |          |     total usage     algorithm
# --        -------  ------  --------   --------  -----------------  -----------------------------
# -- Local: meryl      4 GB    2 CPUs x   1 job      4 GB    2 CPUs  (k-mer counting)
# -- Local: cormhap    4 GB    2 CPUs x   1 job      4 GB    2 CPUs  (overlap detection with mhap)
# -- Local: obtovl     4 GB    2 CPUs x   1 job      4 GB    2 CPUs  (overlap detection)
# -- Local: utgovl     4 GB    2 CPUs x   1 job      4 GB    2 CPUs  (overlap detection)
# -- Local: ovb        4 GB    1 CPU  x   1 job      4 GB    1 CPU   (overlap store bucketizer)
# -- Local: ovs        4 GB    1 CPU  x   1 job      4 GB    1 CPU   (overlap store sorting)
# -- Local: red        4 GB    2 CPUs x   1 job      4 GB    2 CPUs  (read error detection)
# -- Local: oea        4 GB    1 CPU  x   1 job      4 GB    1 CPU   (overlap error adjustment)
# -- Local: bat        4 GB    2 CPUs x   1 job      4 GB    2 CPUs  (contig construction with bogart)
# -- Local: gfa        4 GB    2 CPUs x   1 job      4 GB    2 CPUs  (GFA alignment and processing)
# --
# -- Found Nanopore uncorrected reads in the input files.
# --
# -- Generating assembly 'agalactiae' in '/home/jovyan/notebooks/data/agalactiae/canu_output'
# --
# -- Parameters:
# --
# --  genomeSize        4600000
# --
# --  Overlap Generation Limits:
# --    corOvlErrorRate 0.3200 ( 32.00%)
# --    obtOvlErrorRate 0.1440 ( 14.40%)
# --    utgOvlErrorRate 0.1440 ( 14.40%)
# --
# --  Overlap Processing Limits:
# --    corErrorRate    0.5000 ( 50.00%)
# --    obtErrorRate    0.1440 ( 14.40%)
# --    utgErrorRate    0.1440 ( 14.40%)
# --    cnsErrorRate    0.1920 ( 19.20%)
# --
# --
# -- BEGIN CORRECTION
# --
# ----------------------------------------
# -- Starting command on Fri Apr 27 15:17:24 2018 with 38.086 GB free disk space
#
#     cd .
#     /home/jovyan/software/canu/Linux-amd64/bin/sqStoreCreate \
#       -o ./agalactiae.seqStore.BUILDING \
#       -minlength 50 \
#       ./agalactiae.seqStore.ssi \
#     > ./agalactiae.seqStore.BUILDING.err 2>&1
#
# -- Finished on Fri Apr 27 15:17:25 2018 (one second) with 38.077 GB free disk space
# ----------------------------------------
# --
# -- In sequence store './agalactiae.seqStore':
# --   Found 3604 reads.
# --   Found 34840031 bases (7.57 times coverage).
# --
# --   Read length histogram (one '*' equals 30.55 reads):
# --        0   4999   2139 **********************************************************************
# --     5000   9999    616 ********************
# --    10000  14999    283 *********
# --    15000  19999    164 *****
# --    20000  24999    101 ***
# --    25000  29999     66 **
# --    30000  34999     54 *
# --    35000  39999     29
# --    40000  44999     26
# --    45000  49999     18
# --    50000  54999     13
# --    55000  59999      7
# --    60000  64999     15
# --    65000  69999      6
# --    70000  74999      7
# --    75000  79999      2
# --    80000  84999      6
# --    85000  89999      5
# --    90000  94999      4
# --    95000  99999      3
# --   100000 104999      1
# --   105000 109999      4
# --   110000 114999      3
# --   115000 119999      2
# --   120000 124999      2
# --   125000 129999      1
# --   130000 134999      2
# --   135000 139999      1
# --   140000 144999      2
# --   145000 149999      1
# --   150000 154999      1
# --   155000 159999      3
# --   160000 164999      1
# --   165000 169999      0
# --   170000 174999      0
# --   175000 179999      3
# --   180000 184999      1
# --   185000 189999      2
# --   190000 194999      2
# --   195000 199999      0
# --   200000 204999      1
# --   205000 209999      0
# --   210000 214999      0
# --   215000 219999      0
# --   220000 224999      0
# --   225000 229999      0
# --   230000 234999      0
# --   235000 239999      1
# --   240000 244999      0
# --   245000 249999      0
# --   250000 254999      0
# --   255000 259999      1
# --   260000 264999      0
# --   265000 269999      0
# --   270000 274999      0
# --   275000 279999      1
# --   280000 284999      0
# --   285000 289999      1
# --   290000 294999      0
# --   295000 299999      0
# --   300000 304999      0
# --   305000 309999      0
# --   310000 314999      0
# --   315000 319999      0
# --   320000 324999      0
# --   325000 329999      0
# --   330000 334999      0
# --   335000 339999      0
# --   340000 344999      0
# --   345000 349999      1
# --   350000 354999      0
# --   355000 359999      0
# --   360000 364999      0
# --   365000 369999      0
# --   370000 374999      0
# --   375000 379999      1
# --   380000 384999      0
# --   385000 389999      1
# --
# -- Running jobs.  First attempt out of 2.
# ----------------------------------------
# -- Starting 'meryl' concurrent execution on Fri Apr 27 15:17:25 2018 with 38.077 GB free disk space (1 processes; 1 concurrently)
#
#     cd correction/0-mercounts
#     ./meryl.sh 1 > ./meryl.000001.out 2>&1
#
# -- Finished on Fri Apr 27 15:17:36 2018 (11 seconds) with 37.956 GB free disk space
# ----------------------------------------
# -- Meryl finished successfully.
# --
# --  16-mers                                                                                           Fraction
# --    Occurrences   NumMers                                                                         Unique Total
# --       1-     1  28645526 *******************************************************************--> 0.9267 0.8235
# --       2-     2   1748994 ********************************************************************** 0.9833 0.9240
# --       3-     4    393824 ***************                                                        0.9933 0.9507
# --       5-     7     60200 **                                                                     0.9971 0.9651
# --       8-    11     25634 *                                                                      0.9983 0.9721
# --      12-    16     19377                                                                        0.9990 0.9786
# --      17-    22     11297                                                                        0.9996 0.9862
# --      23-    29      2275                                                                        0.9999 0.9913
# --      30-    37       719                                                                        0.9999 0.9926
# --      38-    46       450                                                                        0.9999 0.9933
# --      47-    56       280                                                                        1.0000 0.9938
# --      57-    67       227                                                                        1.0000 0.9942
# --      68-    79       160                                                                        1.0000 0.9946
# --      80-    92       147                                                                        1.0000 0.9949
# --      93-   106       106                                                                        1.0000 0.9953
# --     107-   121        87                                                                        1.0000 0.9956
# --     122-   137        66                                                                        1.0000 0.9958
# --     138-   154        69                                                                        1.0000 0.9961
# --     155-   172        43                                                                        1.0000 0.9964
# --     173-   191        24                                                                        1.0000 0.9966
# --     192-   211        20                                                                        1.0000 0.9967
# --     212-   232        20                                                                        1.0000 0.9968
# --     233-   254         7                                                                        1.0000 0.9969
# --     255-   277         7                                                                        1.0000 0.9970
# --     278-   301         7                                                                        1.0000 0.9971
# --     302-   326        14                                                                        1.0000 0.9971
# --     327-   352        14                                                                        1.0000 0.9972
# --     353-   379        11                                                                        1.0000 0.9974
# --     380-   407         8                                                                        1.0000 0.9975
# --     408-   436         9                                                                        1.0000 0.9976
# --     437-   466         9                                                                        1.0000 0.9977
# --     467-   497         2                                                                        1.0000 0.9978
# --     498-   529        12                                                                        1.0000 0.9978
# --     530-   562         5                                                                        1.0000 0.9980
# --     563-   596         7                                                                        1.0000 0.9981
# --     597-   631         5                                                                        1.0000 0.9982
# --     632-   667         5                                                                        1.0000 0.9983
# --     668-   704         2                                                                        1.0000 0.9984
# --     705-   742         1                                                                        1.0000 0.9984
# --     743-   781         3                                                                        1.0000 0.9985
# --     782-   821         1                                                                        1.0000 0.9985
# --
# --        7424 (max occurrences)
# --     6140445 (total mers, non-unique)
# --     2264160 (distinct mers, non-unique)
# --    28645526 (unique mers)
# -- For mhap overlapping, set repeat k-mer threshold to 347.
# --
# -- Found 34785971 16-mers; 30909686 distinct and 28645526 unique.  Largest count 7424.
# --
# -- OVERLAPPER (mhap) (correction)
# --
# -- Set corMhapSensitivity=high based on read coverage of 7.
# --
# -- PARAMETERS: hashes=768, minMatches=2, threshold=0.78
# --
# -- Given 4 GB, can fit 6000 reads per block.
# -- For 2 blocks, set stride to 2 blocks.
# -- Logging partitioning to 'correction/1-overlapper/partitioning.log'.
# -- Configured 1 mhap precompute jobs.
# -- Configured 1 mhap overlap jobs.
# --
# -- Running jobs.  First attempt out of 2.
# ----------------------------------------
# -- Starting 'cormhap' concurrent execution on Fri Apr 27 15:17:37 2018 with 38.077 GB free disk space (1 processes; 1 concurrently)
#
#     cd correction/1-overlapper
#     ./precompute.sh 1 > ./precompute.000001.out 2>&1
#
# -- Finished on Fri Apr 27 15:30:15 2018 (758 seconds) with 37.95 GB free disk space
# ----------------------------------------
# -- All 1 mhap precompute jobs finished successfully.
# --
# -- Running jobs.  First attempt out of 2.
# ----------------------------------------
# -- Starting 'cormhap' concurrent execution on Fri Apr 27 15:30:15 2018 with 37.95 GB free disk space (1 processes; 1 concurrently)
#
#     cd correction/1-overlapper
#     ./mhap.sh 1 > ./mhap.000001.out 2>&1
#
# -- Finished on Fri Apr 27 15:30:39 2018 (24 seconds) with 37.947 GB free disk space
# ----------------------------------------
# -- Found 1 mhap overlap output files.
# ----------------------------------------
# -- Starting command on Fri Apr 27 15:30:39 2018 with 37.947 GB free disk space
#
#     cd correction
#     /home/jovyan/software/canu/Linux-amd64/bin/ovStoreConfig \
#      -S ./agalactiae.seqStore \
#      -M 4-4 \
#      -L ./1-overlapper/ovljob.files \
#      -create ./agalactiae.ovlStore.config \
#      > ./agalactiae.ovlStore.config.txt \
#     2> ./agalactiae.ovlStore.config.err
#
# -- Finished on Fri Apr 27 15:30:39 2018 (lickety-split) with 37.947 GB free disk space
# ----------------------------------------
# --
# -- Creating overlap store correction/agalactiae.ovlStore using:
# --      1 bucket
# --      1 slice
# --        using at most 1 GB memory each
# ----------------------------------------
# -- Starting command on Fri Apr 27 15:30:39 2018 with 37.947 GB free disk space
#
#     cd correction
#     /home/jovyan/software/canu/Linux-amd64/bin/ovStoreBuild \
#      -O ./agalactiae.ovlStore.BUILDING \
#      -S ./agalactiae.seqStore \
#      -C ./agalactiae.ovlStore.config \
#      > ./agalactiae.ovlStore.err 2>&1
#
# -- Finished on Fri Apr 27 15:30:40 2018 (one second) with 37.923 GB free disk space
# ----------------------------------------
# -- Checking store.
# ----------------------------------------
# -- Starting command on Fri Apr 27 15:30:40 2018 with 37.923 GB free disk space
#
#     cd correction
#     /home/jovyan/software/canu/Linux-amd64/bin/ovStoreDump \
#      -S ./agalactiae.seqStore \
#      -O ./agalactiae.ovlStore \
#      -counts \
#      > ./agalactiae.ovlStore/counts.dat 2> ./agalactiae.ovlStore/counts.err
#
# -- Finished on Fri Apr 27 15:30:40 2018 (fuirously fast) with 37.923 GB free disk space
# ----------------------------------------
# --
# -- Overlap store 'correction/agalactiae.ovlStore' successfully constructed.
# -- Found 375014 overlaps for 2360 reads; 1244 reads have no overlaps.
# --
# --
# -- Purged 0.091 GB in 3 overlap output files.
# -- Set corMinCoverage=0 based on read coverage of 7.
# -- Global filter scores will be estimated.
# -- Computing correction layouts.
# ----------------------------------------
# -- Starting command on Fri Apr 27 15:30:40 2018 with 38.014 GB free disk space
#
#     cd correction
#     /home/jovyan/software/canu/Linux-amd64/bin/generateCorrectionLayouts \
#       -S ./agalactiae.seqStore \
#       -O ./agalactiae.ovlStore \
#       -C ./agalactiae.corStore.WORKING \
#       -ec 0 \
#       -eC 80 \
#     > ./agalactiae.corStore.err 2>&1
#
# -- Finished on Fri Apr 27 15:30:40 2018 (in the blink of an eye) with 38.012 GB free disk space
# ----------------------------------------
# -- Computing correction layouts.
# ----------------------------------------
# -- Starting command on Fri Apr 27 15:30:40 2018 with 38.012 GB free disk space
#
#     cd correction/2-correction
#     /home/jovyan/software/canu/Linux-amd64/bin/filterCorrectionLayouts \
#       -S  ../agalactiae.seqStore \
#       -C  ../agalactiae.corStore \
#       -R  ./agalactiae.readsToCorrect.WORKING \
#       -cc 0 \
#       -cl 50 \
#       -g  4600000 \
#       -c  40 \
#     > ./agalactiae.readsToCorrect.err 2>&1
#
# -- Finished on Fri Apr 27 15:30:40 2018 (lickety-split) with 38.011 GB free disk space
# ----------------------------------------
# --                             original      original
# --                            raw reads     raw reads
# --   category                w/overlaps  w/o/overlaps
# --   -------------------- ------------- -------------
# --   Number of Reads               2322          1282
# --   Number of Bases           18973958         64708
# --   Coverage                     4.125         0.014
# --   Median                        2277             0
# --   Mean                          8171            50
# --   N50                          30977          3090
# --   Minimum                         50             0
# --   Maximum                     388351          8714
# --
# --                                        --------corrected---------  ----------rescued----------
# --                             evidence                     expected                     expected
# --   category                     reads            raw     corrected            raw     corrected
# --   -------------------- -------------  ------------- -------------  ------------- -------------
# --   Number of Reads               2360           2321          2321              0             0
# --   Number of Bases           19038666       18596559      16469975              0             0
# --   Coverage                     4.139          4.043         3.580          0.000         0.000
# --   Median                        2257           2277          1520              0             0
# --   Mean                          8067           8012          7096              0             0
# --   N50                          30899          29505         32724              0             0
# --   Minimum                         50             50             4              0             0
# --   Maximum                     388351         388351        319526              0             0
# --
# --                        --------uncorrected--------
# --                                           expected
# --   category                       raw     corrected
# --   -------------------- ------------- -------------
# --   Number of Reads               1283          1283
# --   Number of Bases             442107        320859
# --   Coverage                     0.096         0.070
# --   Median                           0             0
# --   Mean                           344           250
# --   N50                              0             0
# --   Minimum                          0             0
# --   Maximum                     377399        320859
# --
# --   Maximum Memory          4028799956
# --
# -- ERROR
# -- ERROR
# -- ERROR  Found 1 machine configuration:
# -- ERROR    class0 - 1 machines with 2 cores with 4 GB memory each.
# -- ERROR
# -- ERROR  Task cor can't run on any available machines.
# -- ERROR  It is requesting:
# -- ERROR    corMemory=15 memory (gigabytes)
# -- ERROR    corThreads=4 threads
# -- ERROR
# -- ERROR  No available machine configuration can run this task.
# -- ERROR
# -- ERROR  Possible solutions:
# -- ERROR    Change corMemory and/or corThreads
# -- ERROR
#
# ABORT:
# ABORT: Canu snapshot v1.7 +137 changes (r8829 73d5caa1b1087b65f7853ecbebc1bb1dcbd1bc14)
# ABORT: Don't panic, but a mostly harmless error occurred and Canu stopped.
# ABORT: Try restarting.  If that doesn't work, ask for help.
# ABORT:
# ABORT:   task cor failed to find a configuration to run on.
# ABORT:
# : 1

# %% [markdown]
# ### Racon
#
# [Racon](https://github.com/isovic/racon) is a consensus module to correct raw contigs generated by rapid assembly methods which do not include a consensus step. We will take our Canu result in FASTA and the raw reads in FASTQ and generate a new FASTA contig file.
#
# Before running Racon, we must align the Canu output to the raw reads file and take the overlaps file in PAF as a parameter for Racon command. This can be done using for example minimap, a rapid aligner for ONT reads.

# %%
minimap data/agalactiae/canu_output/agalactiae.contigs.fasta \
        data/agalactiae/merged-output.fastq \
        > agalactaiae.paf

# %% [markdown]
# Racon parameters:
# - -t: Number of threads
# - Raw reads (FASTQ).
# - Overlaps in (PAF).
# - Canu output (FASTA)
# - Racon output file name (FASTA)

# %%
racon -t 48 \
    data/agalactiae/output/merged-output.fastq \ 
    agalactiae.paf \ 
    data/agalactiae/canu/agalactiae.contigs.fasta \ 
    data/agalactiae_racon.contigs.fasta

# %% [markdown]
# ### Pilon (Requires Illumina reads)
#
# [Pilon](https:github.com/broadinstitute/pilon) is a tool that can be used to improve draft assembly as our case and find variation among strains. It Requires as input a FASTA file and a BAM file of reads aligned to the input FASTA file. At this point, we have the racon contigs file and our reads file (ONT and Illumina reads). We will use the racon contigs file and a BAM file produced by de alignment of ILlumina reads against that contigs file to generate our final result with Pilon.
#
# In first place, we need to align our Illumina reads against the racon contigs file. We are using bwa-mem so first we have to index the reference file (racon contigs) and then perform the alignment of the Illumina reads. In order to have the BAM file required by Pilon, we are using samtools to convert bwa output in FASTA to the BAM format.

# %%
bwa index data/agalactaie_racon.contigs.fasta

# %%
#Illumina data not included in repository
bwa mem -t 48 \
        data/agalactaie_racon.contigs.fasta  \
        data/Data_Ilumina/Raw/WGS_bacterialIsolates_MiSeq_training-33608589/Sagalactiae_HRC-41106565/Sagal_S5_L001_R1_001.fastq.gz \
        data/Data_Ilumina/Raw/WGS_bacterialIsolates_MiSeq_training-33608589/Sagalactiae_HRC-41106565/Sagal_S5_L001_R2_001.fastq.gz \
        | samtools view -S -b -u - | samtools sort - data/bwa_aligned_reads

# %% [markdown]
# Finally we index the BAM file an run the Pilon jar:

# %%
samtools index data/bwa_aligned_reads.bam

# %% [markdown]
# Pilon arguments:
# - --threads: Number of threads
# - --genome: The FASTA input file (racon contigs)
# - --bam: BAM file (generated by bwa and samtools)
# - --outdir and --output: Output directory and filename

# %%
java -Xmx128g -XX:+UseConcMarkSweepGC \ 
      -XX:-UseGCOverheadLimit \ 
      -jar /home/jovyan/software/pilon/pilon-1.22.jar \ 
      --threads 2 \ 
      --genome data/agalactaie_racon.contigs.fasta \ 
      --bam data/bwa_aligned_reads.bam \ 
      --outdir data/agalactiae/pilon_output \ 
      --output pilon.contigs
